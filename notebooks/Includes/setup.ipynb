# %%
my_name = "Daniel Lopez"
anothe_var = 3.14

# %% [markdown]
# ### Use this command to copy the data in /data dir to the Volume in databricks

# %%
# %fs cp  /Workspace/Users/de.lopezbarron@gmail.com/databricks-experiments/data/iris.csv /Volumes/workspace/testing_schema/testing_volumne/iris.csv
