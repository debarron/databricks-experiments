# %%
print("hello world")

# %%
# %sql
select 'hello there'

# %% [markdown]
# # This is a magic command to write markdown
# f

# %%
# %run ./Includes/setup

# %%
print(my_name)
print(anothe_var)

# %%
# %fs ls '/databricks-datasets'

# %%
# %fs ls '/databricks-datasets/flowers/delta'
